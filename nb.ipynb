# %%
from rat.prototype import *
import seaborn
# Out:
# 280129751383477787709680355788933400233
# 10639553241260489018946473423816677180012041638291594185912836949208385977352907891167744602291878520238729104541961
# 1
# (9, 1489288847906362695773557739)
# True
# True

# %%
data_13 = explore_fp(13)
data_3 = explore_fp(3)

# %%
data_13
# Out:
# shape: (4_822_416, 3)
# ┌──────┬──────┬─────┐
# │ x    ┆ y    ┆ z   │
# │ ---  ┆ ---  ┆ --- │
# │ i64  ┆ i64  ┆ i64 │
# ╞══════╪══════╪═════╡
# │ 1    ┆ 1    ┆ 1   │
# │ 1    ┆ 2    ┆ 0   │
# │ 1    ┆ 3    ┆ 0   │
# │ 1    ┆ 4    ┆ 0   │
# │ 1    ┆ 5    ┆ 0   │
# │ …    ┆ …    ┆ …   │
# │ 2196 ┆ 2192 ┆ 1   │
# │ 2196 ┆ 2193 ┆ 1   │
# │ 2196 ┆ 2194 ┆ 1   │
# │ 2196 ┆ 2195 ┆ 1   │
# │ 2196 ┆ 2196 ┆ 1   │
# └──────┴──────┴─────┘

# %%
data_13.describe()
# Out:
# shape: (9, 4)
# ┌────────────┬────────────┬────────────┬────────────┐
# │ statistic  ┆ x          ┆ y          ┆ z          │
# │ ---        ┆ ---        ┆ ---        ┆ ---        │
# │ str        ┆ f64        ┆ f64        ┆ f64        │
# ╞════════════╪════════════╪════════════╪════════════╡
# │ count      ┆ 4.822416e6 ┆ 4.822416e6 ┆ 4.822416e6 │
# │ null_count ┆ 0.0        ┆ 0.0        ┆ 0.0        │
# │ mean       ┆ 1098.5     ┆ 1098.5     ┆ 3.678102   │
# │ std        ┆ 633.930596 ┆ 633.930596 ┆ 34.467822  │
# │ min        ┆ 1.0        ┆ 1.0        ┆ 0.0        │
# │ 25%        ┆ 550.0      ┆ 550.0      ┆ 0.0        │
# │ 50%        ┆ 1099.0     ┆ 1099.0     ┆ 1.0        │
# │ 75%        ┆ 1647.0     ┆ 1647.0     ┆ 1.0        │
# │ max        ┆ 2196.0     ┆ 2196.0     ┆ 2196.0     │
# └────────────┴────────────┴────────────┴────────────┘

# %%
data_3.write_csv("data_3.csv")
data_13.write_csv("data_13.csv")

# %%
data_3 = visualize_fp(3)

# %%
seaborn.heatmap(data_3)
# Out:
# <Axes: >

# %%
seaborn.heatmap(visualize_fp(5))
# Out:
# <Axes: >
