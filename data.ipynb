# %%
from rat import *
# Out:
# 280129751383477787709680355788933400233
# 10639553241260489018946473423816677180012041638291594185912836949208385977352907891167744602291878520238729104541961
# 1
# (9, 1489288847906362695773557739)
# True
# True

# %%
fp_df(3)
# Out:
# shape: (4, 7)
# ┌──────┬─────┬─────┬─────────┬─────┬─────┬─────┐
# │ yinv ┆ y   ┆ x   ┆ x_div_y ┆ z   ┆ p   ┆ p3  │
# │ ---  ┆ --- ┆ --- ┆ ---     ┆ --- ┆ --- ┆ --- │
# │ i64  ┆ i64 ┆ i64 ┆ i64     ┆ i64 ┆ i32 ┆ i32 │
# ╞══════╪═════╪═════╪═════════╪═════╪═════╪═════╡
# │ 1    ┆ 1   ┆ 1   ┆ 1       ┆ 1   ┆ 3   ┆ 27  │
# │ 14   ┆ 2   ┆ 1   ┆ 14      ┆ 14  ┆ 3   ┆ 27  │
# │ 1    ┆ 1   ┆ 2   ┆ 2       ┆ 2   ┆ 3   ┆ 27  │
# │ 14   ┆ 2   ┆ 2   ┆ 28      ┆ 1   ┆ 3   ┆ 27  │
# └──────┴─────┴─────┴─────────┴─────┴─────┴─────┘

# %%
inv_df(4)
# Out:
# shape: (2, 5)
# ┌─────┬─────┬─────┬──────┬─────────┐
# │ p   ┆ p3  ┆ y   ┆ yinv ┆ y_div_y │
# │ --- ┆ --- ┆ --- ┆ ---  ┆ ---     │
# │ i32 ┆ i32 ┆ i64 ┆ i64  ┆ i64     │
# ╞═════╪═════╪═════╪══════╪═════════╡
# │ 4   ┆ 64  ┆ 1   ┆ 1    ┆ 1       │
# │ 4   ┆ 64  ┆ 3   ┆ 43   ┆ 129     │
# └─────┴─────┴─────┴──────┴─────────┘

# %%
paint_fp(3)

# %%
paint_fp(7)

# %%
simp_df(7)
# Out:
# shape: (36, 3)
# ┌─────┬─────┬─────┐
# │ x   ┆ y   ┆ z   │
# │ --- ┆ --- ┆ --- │
# │ i64 ┆ i64 ┆ i64 │
# ╞═════╪═════╪═════╡
# │ 1   ┆ 1   ┆ 1   │
# │ 1   ┆ 2   ┆ 172 │
# │ 1   ┆ 3   ┆ 229 │
# │ 1   ┆ 4   ┆ 86  │
# │ 1   ┆ 5   ┆ 206 │
# │ …   ┆ …   ┆ …   │
# │ 6   ┆ 2   ┆ 3   │
# │ 6   ┆ 3   ┆ 2   │
# │ 6   ┆ 4   ┆ 173 │
# │ 6   ┆ 5   ┆ 207 │
# │ 6   ┆ 6   ┆ 1   │
# └─────┴─────┴─────┘

# %%
paint_fp(5)

# %%
df = fp_df(5)
df.filter(pl.col('y') == 4)
# Out:
# shape: (4, 7)
# ┌──────┬─────┬─────┬─────────┬─────┬─────┬─────┐
# │ yinv ┆ y   ┆ x   ┆ x_div_y ┆ z   ┆ p   ┆ p3  │
# │ ---  ┆ --- ┆ --- ┆ ---     ┆ --- ┆ --- ┆ --- │
# │ i64  ┆ i64 ┆ i64 ┆ i64     ┆ i64 ┆ i32 ┆ i32 │
# ╞══════╪═════╪═════╪═════════╪═════╪═════╪═════╡
# │ 94   ┆ 4   ┆ 1   ┆ 94      ┆ 94  ┆ 5   ┆ 125 │
# │ 94   ┆ 4   ┆ 2   ┆ 188     ┆ 63  ┆ 5   ┆ 125 │
# │ 94   ┆ 4   ┆ 3   ┆ 282     ┆ 32  ┆ 5   ┆ 125 │
# │ 94   ┆ 4   ┆ 4   ┆ 376     ┆ 1   ┆ 5   ┆ 125 │
# └──────┴─────┴─────┴─────────┴─────┴─────┴─────┘

# %%
df.filter(pl.col('x') == 1)
# Out:
# shape: (4, 7)
# ┌──────┬─────┬─────┬─────────┬─────┬─────┬─────┐
# │ yinv ┆ y   ┆ x   ┆ x_div_y ┆ z   ┆ p   ┆ p3  │
# │ ---  ┆ --- ┆ --- ┆ ---     ┆ --- ┆ --- ┆ --- │
# │ i64  ┆ i64 ┆ i64 ┆ i64     ┆ i64 ┆ i32 ┆ i32 │
# ╞══════╪═════╪═════╪═════════╪═════╪═════╪═════╡
# │ 1    ┆ 1   ┆ 1   ┆ 1       ┆ 1   ┆ 5   ┆ 125 │
# │ 63   ┆ 2   ┆ 1   ┆ 63      ┆ 63  ┆ 5   ┆ 125 │
# │ 42   ┆ 3   ┆ 1   ┆ 42      ┆ 42  ┆ 5   ┆ 125 │
# │ 94   ┆ 4   ┆ 1   ┆ 94      ┆ 94  ┆ 5   ┆ 125 │
# └──────┴─────┴─────┴─────────┴─────┴─────┴─────┘

# %%
paint_fp(7)

# %%
fp_df(5)
# Out:
# shape: (16, 7)
# ┌──────┬─────┬─────┬─────────┬─────┬─────┬─────┐
# │ yinv ┆ y   ┆ x   ┆ x_div_y ┆ z   ┆ p   ┆ p3  │
# │ ---  ┆ --- ┆ --- ┆ ---     ┆ --- ┆ --- ┆ --- │
# │ i64  ┆ i64 ┆ i64 ┆ i64     ┆ i64 ┆ i32 ┆ i32 │
# ╞══════╪═════╪═════╪═════════╪═════╪═════╪═════╡
# │ 1    ┆ 1   ┆ 1   ┆ 1       ┆ 1   ┆ 5   ┆ 125 │
# │ 63   ┆ 2   ┆ 1   ┆ 63      ┆ 63  ┆ 5   ┆ 125 │
# │ 42   ┆ 3   ┆ 1   ┆ 42      ┆ 42  ┆ 5   ┆ 125 │
# │ 94   ┆ 4   ┆ 1   ┆ 94      ┆ 94  ┆ 5   ┆ 125 │
# │ 1    ┆ 1   ┆ 2   ┆ 2       ┆ 2   ┆ 5   ┆ 125 │
# │ …    ┆ …   ┆ …   ┆ …       ┆ …   ┆ …   ┆ …   │
# │ 94   ┆ 4   ┆ 3   ┆ 282     ┆ 32  ┆ 5   ┆ 125 │
# │ 1    ┆ 1   ┆ 4   ┆ 4       ┆ 4   ┆ 5   ┆ 125 │
# │ 63   ┆ 2   ┆ 4   ┆ 252     ┆ 2   ┆ 5   ┆ 125 │
# │ 42   ┆ 3   ┆ 4   ┆ 168     ┆ 43  ┆ 5   ┆ 125 │
# │ 94   ┆ 4   ┆ 4   ┆ 376     ┆ 1   ┆ 5   ┆ 125 │
# └──────┴─────┴─────┴─────────┴─────┴─────┴─────┘

# %%
paint_fp(11)

# %%
df_11 = fp_df(11)
z_set = set(df_11['z'])
print(z_set)
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8, 9, 134, 267, 1036, 1165, 268, 10, 400, 148, 533, 534, 149, 666, 667, 668, 669, 670, 799, 800, 1184, 932, 167, 296, 1065, 1066, 1198, 951, 952, 571, 444, 445, 446, 191, 832, 833, 447, 333, 334, 335, 592, 1110, 222, 889, 223, 762, 740, 999, 1000, 500, 1141, 1142, 888, 761, 890, 381}

# %%
inv_df(11)
# Out:
# 11
# shape: (10, 5)
# ┌─────┬──────┬─────┬──────┬─────────┐
# │ p   ┆ p3   ┆ y   ┆ yinv ┆ y_div_y │
# │ --- ┆ ---  ┆ --- ┆ ---  ┆ ---     │
# │ i32 ┆ i32  ┆ i64 ┆ i64  ┆ i64     │
# ╞═════╪══════╪═════╪══════╪═════════╡
# │ 11  ┆ 1331 ┆ 1   ┆ 1    ┆ 1       │
# │ 11  ┆ 1331 ┆ 2   ┆ 666  ┆ 1332    │
# │ 11  ┆ 1331 ┆ 3   ┆ 444  ┆ 1332    │
# │ 11  ┆ 1331 ┆ 4   ┆ 333  ┆ 1332    │
# │ 11  ┆ 1331 ┆ 5   ┆ 1065 ┆ 5325    │
# │ 11  ┆ 1331 ┆ 6   ┆ 222  ┆ 1332    │
# │ 11  ┆ 1331 ┆ 7   ┆ 1141 ┆ 7987    │
# │ 11  ┆ 1331 ┆ 8   ┆ 832  ┆ 6656    │
# │ 11  ┆ 1331 ┆ 9   ┆ 148  ┆ 1332    │
# │ 11  ┆ 1331 ┆ 10  ┆ 1198 ┆ 11980   │
# └─────┴──────┴─────┴──────┴─────────┘

# %%
paint_inf(11)

# %%
P = NaturalNumber(5)
P3 = P.cubed()

print(P3.mul_group_list())
# Out:
# [1, 2, 3, 4, 6, 7, 8, 9, 11, 12, 13, 14, 16, 17, 18, 19, 21, 22, 23, 24, 26, 27, 28, 29, 31, 32, 33, 34, 36, 37, 38, 39, 41, 42, 43, 44, 46, 47, 48, 49, 51, 52, 53, 54, 56, 57, 58, 59, 61, 62, 63, 64, 66, 67, 68, 69, 71, 72, 73, 74, 76, 77, 78, 79, 81, 82, 83, 84, 86, 87, 88, 89, 91, 92, 93, 94, 96, 97, 98, 99, 101, 102, 103, 104, 106, 107, 108, 109, 111, 112, 113, 114, 116, 117, 118, 119, 121, 122, 123, 124]

# %%
# exhaustive_attack()
