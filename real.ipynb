# %%
from rat import *
# Out:
# 280129751383477787709680355788933400233
# 10639553241260489018946473423816677180012041638291594185912836949208385977352907891167744602291878520238729104541961
# 1
# (9, 1489288847906362695773557739)
# True
# True

# %%
paint_fp(3)
# Out:
# <Axes: >

# %%
paint_fp(4)
# Out:
# <Axes: >

# %%
paint_fp(5)
# Out:
# <Axes: >

# %%
paint_fp(7)
# Out:
# <Axes: >

# %%
paint_fp(13)
# Out:
# <Axes: >

# %%
paint_fp(97)
# Out:
# <Axes: >

# %%
paint_fp(6)
# Out:
# <Axes: >

# %%
# f8 = fp_composite(p)
n = NaturalNumber(8)
n.is_prime()
# Out:
# False

# %%
list(n.mul_group())
n = NaturalNumber(190)

# %%
list(n.mul_group())
f7 = fp_composite(7)

# %%
f7(6, 1)
# Out:
# 6

# %%
fc = fp_composite(8)

fc(5, 3)
n = NaturalNumber(8)
n.mul_group_list()
# Out:
# [1, 3, 5, 7]

# %%
n.grid()
paint_fp(10)
# Out:
# <Axes: >

# %%
paint_fp(200)
# Out:
# <Axes: >

# %%
paint_fp(13)
# Out:
# <Axes: >

# %%
paint_fp(15)
# Out:
# <Axes: >

# %%
# paint_fp(5 * 6)

# %%
# paint_fp(5 * 7)

# %%
# NaturalNumber(5 * 7).mul_group_list()

# %%
paint_fp(13)
# Out:
# <Axes: >

# %%
paint_fp(17)
# Out:
# <Axes: >

# %%
paint_fp(19)
# Out:
# <Axes: >

# %%
paint_fp(811)
# Out:
# <Axes: >

# %%
paint_fp(27)
# Out:
# <Axes: >

# %%
fp_grid(27)
# Out:
# array([[       nan,        nan,        nan,        nan,        nan,
#                nan,        nan,        nan,        nan,        nan,
#                nan,        nan,        nan,        nan,        nan,
#                nan,        nan,        nan,        nan,        nan,
#                nan,        nan,        nan,        nan,        nan,
#                nan,        nan],
#        [       nan, 1.0000e+00, 2.0000e+00,        nan, 4.0000e+00,
#         5.0000e+00,        nan, 7.0000e+00, 8.0000e+00,        nan,
#         1.0000e+01, 1.1000e+01,        nan, 1.3000e+01, 1.4000e+01,
#                nan, 1.6000e+01, 1.7000e+01,        nan, 1.9000e+01,
#         2.0000e+01,        nan, 2.2000e+01, 2.3000e+01,        nan,
#         2.5000e+01, 2.6000e+01],
#        [       nan, 9.8420e+03, 1.0000e+00,        nan, 2.0000e+00,
#         9.8440e+03,        nan, 9.8450e+03, 4.0000e+00,        nan,
#         5.0000e+00, 9.8470e+03,        nan, 9.8480e+03, 7.0000e+00,
# ...

# %%
df_27 = fp_df(27)

# %%
import altair as alt

alt.Chart(df_27).mark_bar().encode(
    x='z',
    y='count()'
)
# Out:
# alt.Chart(...)

# %%
fp_hist(3)
# Out:
# alt.Chart(...)

# %%
fp_hist(5)
# Out:
# alt.Chart(...)

# %%
fp_hist(7)
# Out:
# alt.Chart(...)

# %%
fp_df(661)
# Out:
# shape: (435_600, 7)
# ┌───────────┬─────┬─────┬──────────────┬───────────┬─────┬───────────┐
# │ yinv      ┆ y   ┆ x   ┆ x_div_y      ┆ z         ┆ p   ┆ p3        │
# │ ---       ┆ --- ┆ --- ┆ ---          ┆ ---       ┆ --- ┆ ---       │
# │ i64       ┆ i64 ┆ i64 ┆ i64          ┆ i64       ┆ i32 ┆ i32       │
# ╞═══════════╪═════╪═════╪══════════════╪═══════════╪═════╪═══════════╡
# │ 1         ┆ 1   ┆ 1   ┆ 1            ┆ 1         ┆ 661 ┆ 288804781 │
# │ 1         ┆ 1   ┆ 2   ┆ 2            ┆ 144402391 ┆ 661 ┆ 288804781 │
# │ 1         ┆ 1   ┆ 3   ┆ 3            ┆ 192536521 ┆ 661 ┆ 288804781 │
# │ 1         ┆ 1   ┆ 4   ┆ 4            ┆ 216603586 ┆ 661 ┆ 288804781 │
# │ 1         ┆ 1   ┆ 5   ┆ 5            ┆ 231043825 ┆ 661 ┆ 288804781 │
# │ …         ┆ …   ┆ …   ┆ …            ┆ …         ┆ …   ┆ …         │
# │ 287492695 ┆ 660 ┆ 656 ┆ 188595207920 ┆ 251823682 ┆ 661 ┆ 288804781 │
# │ 287492695 ┆ 660 ┆ 657 ┆ 188882700615 ┆ 85718315  ┆ 661 ┆ 288804781 │
# ...

# %%
paint_fp(547)
# Out:
# <Axes: >

# %%
paint_fp(284)
# Out:
# <Axes: >

# %%
paint_fp(7)
# Out:
# <Axes: >

# %%
fp_hist(7)
# Out:
# alt.Chart(...)

# %%
paint_fp(3)
# Out:
# <Axes: >

# %%
fp_df(3)
# Out:
# shape: (4, 7)
# ┌──────┬─────┬─────┬─────────┬─────┬─────┬─────┐
# │ yinv ┆ y   ┆ x   ┆ x_div_y ┆ z   ┆ p   ┆ p3  │
# │ ---  ┆ --- ┆ --- ┆ ---     ┆ --- ┆ --- ┆ --- │
# │ i64  ┆ i64 ┆ i64 ┆ i64     ┆ i64 ┆ i32 ┆ i32 │
# ╞══════╪═════╪═════╪═════════╪═════╪═════╪═════╡
# │ 1    ┆ 1   ┆ 1   ┆ 1       ┆ 1   ┆ 3   ┆ 27  │
# │ 1    ┆ 1   ┆ 2   ┆ 2       ┆ 14  ┆ 3   ┆ 27  │
# │ 20   ┆ 2   ┆ 1   ┆ 20      ┆ 2   ┆ 3   ┆ 27  │
# │ 20   ┆ 2   ┆ 2   ┆ 40      ┆ 1   ┆ 3   ┆ 27  │
# └──────┴─────┴─────┴─────────┴─────┴─────┴─────┘
